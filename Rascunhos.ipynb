# %% [markdown]
# *Rascunhos*

# %%
# Styles de números
0 = None
1 = Bold
4 = Underline
7 = Negative

# %%
# Cor do texto
30 = White
31 = Red 
32 = Green
33 = Yellow
34 = Blue
35 = Purple
36 = LightBlue
37 = Gray - Padrão

# %%
# Back (Fundo)
40 = White
41 = Red 
42 = Green
43 = Yellow
44 = Blue
45 = Purple
46 = LightBlue
47 = Gray - Padrão

# %%
# Teste 1
\033[0;30;41m

# %%
# Teste 2
\033[4;33;44m

# %%
# Teste 3
\033[0;35;43m

# %%
# Teste 4
\033[0;30;42m

# %%
# Teste 5
\033[0;37;47m or \033[m

# %%
# Teste 6
\033[0;37;40m

# %%
print('\033[31;42mSantos')
# Out:
# Santos

# %%
a = 5
b = 7
print('Os valores são \033[35m{}\033[m e \033[36m{}\033[m !'.format(a, b))
# Out:
# Os valores são 5 e 7 !
