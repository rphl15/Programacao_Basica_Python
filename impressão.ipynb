# %%
# https://www.hashtagtreinamentos.com/imprimir-arquivos-com-python

import win32print
import win32api
import os

# %%
for i, p in enumerate(lista_impressoras):
    print(i, p[2])
# Out:
# 0 HP LaserJet Pro MFP 4103 [FD7419] (Fax)
# 1 CMACJ404 (HP LaserJet Pro MFP 4103)
# 2 OneNote (Desktop)
# 3 Microsoft Print to PDF

# %%
impressoras = win32print.EnumPrinters(2)

win32print.SetDefaultPrinter("CMACJ404 (HP LaserJet Pro MFP 4103)")

# %%
arquivos = os.listdir('G:/Drives compartilhados/Qualidade/AVALIAÇÃO DE DESEMPENHO/CQEHAF - Avaliação/relatorios_gerados/')
