# %% [markdown]
# *Estruturas de repetição*

# %%
count = 1 
while count <= 5:
    print(count)
    count += 1

# %%
#range(0, 10, 2):
#range(inicio, parada, incremento)
#Incremento opcional, pode ser negativo

# %%
for n in range(0,10, 2):
    print(n)

# %%
#cancela o laço
break
#reinicia o laço
continue

# %% [markdown]
# *Listas*

# %%
#Criando listas
lst = [1,2,3,4,5]
lst2 = [1,2,3,"4", True]
lst3 = [12,[1,2,3,4,5], "a"]
lst4 = list(range(0,10))
#acesso primeiro elemento -  indexadas em zero
lst[0]
#numero de elementos em uma lista
len(lst)

# %% [markdown]
# *Dicionários, Sets, Tuplas*

# %%
#Dicionario
#Conjunto de chave/valor associados
#Declarados por chaves e separadas por dois pontos
precos = {'Lapis': 5.5, 'Borracha': 7.0, 'Caneta': 6.5}

# %%
#SETS
#Conjuntos não ordenados e não repetidos de elementos
animais = {'Gato', 'Cachorro'}

# %%
#TUPLAS
tp1 = (1,2,3,4,5,6)

# %% [markdown]
# *Numpy*

# %%
import numpy as np
#cria uma matriz unidimensional
a = np.array([12,34,26,18,10])
print(a)
print(a.dtype)

# %% [markdown]
# *Pandas*

# %%
import pandas as pd
dados = pd.read_csv('Arquivo_a_ser_selecionado.csv')

# %% [markdown]
# *Modulos e Pacotes*

# %%
#Módulos - Conjunto de funcionalidades organizadas em arquivos
import statistics
x = statistics.mean(z)
y = statistics.median(z)
#Abreviando o nome usandp o (as)
import statistics as est
x = est.mean(z)
y = est.median(z)

# %%
#Uso sem nome do módulo
from statistics import mean, median
mean()
median()
#Ou
from statistics import *

# %%
#Instalação de pacotes
pip install #nome do pacote

# %% [markdown]
# *Funções*

# %%
#Blocos de Código Reutilizáveis
#Podem ser chamados de qualquer parte do programa
#Podem ser chamados de outros programas

# %%
#função
def imprime ()
    print("Está é a função")
#Executando a função
imprime()

# %%
def imprime(n):
    print(n)
#Executando a função
imprime("Impressão deste texto")

# %%
def potencia(n):
    return n * n
#Executando a função
x = potencia(3)

# %%
def intervalo(inic=1, fim=10):
    for inic in range(1, fim+1):
        print(inic)
        
intervalo(1,10)
intervalo()

# %% [markdown]
# *Funções Padrão*

# %%
#Sem o uso de import
abs()
max()
min()
round()
sum()

# %%
#Modulos Nativos
from statistics import *
mean()
median()
mode()
stdev()
variance()

# %%
# Formatação de textos %s
nome = "Poliana"
texto = "O nome dela é: %s" % (nome)
print(texto)

# %%
# Formatação de numeros inteiros %d
numero =  15
texto = "O numero é: %d" % (numero)
print(texto)

# %%
# Formatação de numeros float %f
numerofloat = 3.14
texto = "O numero é: %f" %(numerofloat)
print(texto)
