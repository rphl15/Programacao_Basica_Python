# %%
import pandas as pd
import numpy as np
import selenium
import time

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# Definindo as datas:
dia_inicial = int(input('DIGITE O PRIMEIRO DIA DO MES: '))
mes = int(input('DIGITE O MES: '))
dia_final = int(input('DIGITE O ULTIMO DIA DO MES: '))
ano = 2026

# %%
data_inicial = f"{dia_inicial:02d}{mes:02d}{ano}"
data_final = f"{dia_final:02d}{mes:02d}{ano}"
print(data_inicial)
print(data_final)
# Out:
# 01032026
# 31032026

# %%
if mes == 1:
    month = "JAN",
elif mes == 2:
    month = "FEV"
elif mes == 3:
    month = "MAR"
elif mes == 4:
    month = "ABR"
elif mes == 5:
    month = "MAI"
elif mes == 6:
    month = "JUN"
elif mes == 7:
    month = "JUL"
elif mes == 8:
    month = "AGO"
elif mes == 9:
    month = "SET"
elif mes == 10:
    month = "OUT"
elif mes == 11:
    month = "NOV"
elif mes == 12:
    month = "DEZ"

# %%
month
# Out:
# 'MAR'

# %%
# Abrindo o navegador
driver = webdriver.Edge()
web = driver.get("https://cma.healthchess.com.br/Clinica/index.xhtml;JSESSIONID=50d81b7c-c8b0-48fc-94af-e100bb2a11e1")

# %%
# Inserindo o login
driver.find_element('xpath', '//*[@id="login"]').send_keys("qualidade")
# Inserindo a senha
driver.find_element('xpath','//*[@id="senha"]').send_keys("qualidade")
# Entrando
driver.find_element('xpath', '//*[@id="btnEntrar"]/span').click()

# %%
# Entrando em Operacional
driver.find_element('xpath', '//*[@id="layout-menu-span-menu-operacional-icone"]').click()
# Entrando em Procedimento
driver.find_element('xpath', '//*[@id="submenu"]/div/ul/li[3]/a/div').click()

# %%
# Colocando a data inicial
driver.find_element('xpath','//*[@id="dataInicio_input"]').clear()
driver.find_element('xpath','//*[@id="dataInicio_input"]').send_keys(data_inicial)

# %%
# Colocando a data final
driver.find_element('xpath','//*[@id="dataTermino_input"]').clear()
driver.find_element('xpath','//*[@id="dataTermino_input"]').send_keys(data_final)

# %%
# Selecionando Hospitas
driver.find_element('xpath','//*[@id="filtroClinica"]').click()
driver.find_element('xpath','//*[@id="filtroClinica_panel"]/div[1]/div[1]/div[2]/span').click()

# Retirando Hospitais que não são feitos a analise
driver.find_element('xpath','//*[@id="filtroClinica_panel"]/div[2]/ul/li[10]/label').click()
driver.find_element('xpath','//*[@id="filtroClinica_panel"]/div[2]/ul/li[7]/label').click()

# %%
# Selecionando filtro avançado
driver.find_element('xpath','//*[@id="j_idt1142"]/span[2]').click()

# %%
# Selecionando a caixa sala
driver.find_element('xpath','//*[@id="filtroSala"]').click()

# Filtrando apenas endoscopias dos hospital
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[5]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[18]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[26]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[32]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[45]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[46]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[53]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[64]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[70]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[76]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[82]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[87]/label').click()
driver.find_element('xpath','//*[@id="filtroSala_panel"]/div[2]/ul/li[95]/label').click()

# %%
# Filtrar todos os dados
driver.find_element('xpath','//*[@id="guia-procedimento-partials-filtros-commandButton-filtrar-botao"]/span').click()

# %%
# Gerar em XLS
driver.find_element('xpath','//*[@id="guia-procedimento-partials-listagem-commandButton-gerarXls"]/span').click()

# %%
# Trazendo o arquivo baixado
download = ('C:/Users/raphael.eugenio/Downloads/')
arquivo = ('ConsultaProcedimento_cma_healthchess_com_br_356512 (5).xlsx')
df = pd.read_excel(download + arquivo)

# Caminho onde será enviado os arquivos
caminho = ('G:/Drives compartilhados/Qualidade/ACURÁCIA/INDICADORES EDA/2026/TESTE/')
# Out:
# c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df['Clínica'].value_counts()
# Out:
# Clínica
# ANALIA FRANCO               990
# ITAIM                       694
# JABAQUARA                   392
# OSASCO                      346
# GUARULHOS                   339
# MORUMBI                     318
# VILA NOVA STAR              314
# CENTRAL OESTE               200
# VILA NOVA STAR - TORRE 2    162
# CENTRAL DO TATUAPÉ          151
# ALPHAVILLE                  116
# SANTA ISABEL                 33
# Name: count, dtype: int64

# %%
# Começando a filtragem e fazendo as movimentações: Itaim
itaim = df['Clínica'].str.contains('ITAIM', case=False, na=False)
df_itaim = df[itaim]
print(df_itaim)
df_itaim.to_excel(f'{caminho}EDA_ITAIM_{month}{ano}.xlsx')
# Out:
#      Data Procedimento                                Data Início/Término  \
# 2     01/03/2026 07:40  Início: 01/03/2026 07:20\n Término: 01/03/2026...
# 3     01/03/2026 07:50  Início: 01/03/2026 08:00\n Término: 01/03/2026...
# 4     01/03/2026 08:10  Início: 01/03/2026 07:40\n Término: 01/03/2026...
# 6     01/03/2026 08:20  Início: 01/03/2026 08:25\n Término: 01/03/2026...
# 9     01/03/2026 09:00  Início: 01/03/2026 08:30\n Término: 01/03/2026...
# ...                ...                                                ...
# 4027  31/03/2026 17:00  Início: 31/03/2026 16:30\n Término: 31/03/2026...
# 4041  31/03/2026 17:50  Início: 31/03/2026 17:00\n Término: 31/03/2026...
# 4044  31/03/2026 18:30  Início: 31/03/2026 18:00\n Término: 31/03/2026...
# 4046  31/03/2026 18:50  Início: 31/03/2026 18:10\n Término: 31/03/2026...
# 4052  31/03/2026 19:40  Início: 31/03/2026 19:00\n Término: 31/03/2026...
#
#                            Paciente    Idade Paciente        NA Clínica  \
# ...

# %%
# Vila Nova Star
vns = df['Clínica'].str.contains('VILA NOVA STAR|VILA NOVA STAR - TORRE 2', case=False, na=False)
df_vns = df[vns]
print(df_vns)
df_vns.to_excel(f'{caminho}EDA_VILA_NOVA_STAR_{month}{ano}.xlsx')
# Out:
#      Data Procedimento                                Data Início/Término  \
# 1     01/03/2026 07:30  Início: 01/03/2026 08:25\n Término: 01/03/2026...
# 23    01/03/2026 11:00  Início: 01/03/2026 11:00\n Término: 01/03/2026...
# 29    01/03/2026 12:00  Início: 01/03/2026 12:05\n Término: 01/03/2026...
# 39    01/03/2026 14:30  Início: 01/03/2026 14:25\n Término: 01/03/2026...
# 65    02/03/2026 08:40  Início: 02/03/2026 08:20\n Término: 02/03/2026...
# ...                ...                                                ...
# 4045  31/03/2026 18:40  Início: 31/03/2026 18:10\n Término: 31/03/2026...
# 4049  31/03/2026 19:10  Início: 31/03/2026 19:07\n Término: 31/03/2026...
# 4050  31/03/2026 19:10  Início: 31/03/2026 18:30\n Término: 31/03/2026...
# 4053  31/03/2026 19:40  Início: 31/03/2026 19:39\n Término: 31/03/2026...
# 4054  31/03/2026 20:10  Início: 31/03/2026 19:10\n Término: 31/03/2026...
#
#                                 Paciente   Idade Paciente        NA  \
# ...

# %%
# Alphaville
alphaville = df['Clínica'].str.contains('ALPHAVILLE', case=False, na=False)
df_alpha = df[alphaville]
print(df_alpha)
df_alpha.to_excel(f'{caminho}EDA_ALPHAVILLE_{month}{ano}.xlsx')
# Out:
#      Data Procedimento                                Data Início/Término  \
#